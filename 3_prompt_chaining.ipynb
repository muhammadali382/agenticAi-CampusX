# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0.2
)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '**Title:** "The Rise of AI in India: Unlocking Opportunities and Transforming Industries"\n\n**I. Introduction**\n\n* Brief overview of AI and its growing importance globally\n* Importance of India as a hub for AI innovation and adoption\n* Thesis statement: India is poised to become a leader in AI adoption, driven by government initiatives, technological advancements, and entrepreneurial spirit.\n\n**II. Government Initiatives and Policies**\n\n* Overview of government initiatives such as:\n\t+ Digital India\n\t+ Make in India\n\t+ Start-up India\n\t+ AI for All (AIFORALL)\n* Analysis of policies and regulations supporting AI adoption, such as:\n\t+ Data Protection Bill\n\t+ National Policy on Artificial Intelligence\n* Discussion of government investments in AI research and development\n\n**III. AI Adoption in Indian Industries**\n\n* Overview of AI adoption in various industries, including:\n\t+ Healthcare: AI-powered diagnosis, personalized medicine, and telemedicine\n\t+ Finance: AI-driven banking, credit scoring, and risk management\n\t+ Education: AI-powered learning platforms, adaptive learning, and virtual assistants\n\t+ Retail: AI-driven customer service, inventory management, and supply chain optimization\n\t+ Manufacturing: AI-powered predictive maintenance, quality control, and supply chain optimization\n* Analysis of success stories and case studies of AI adoption in Indian industries\n\n**IV. AI Start-ups and Entrepreneurship**\n\n* Overview of the Indian AI start-up ecosystem, including:\n\t+ Number of AI start-ups and funding trends\n\t+ Notable AI start-ups and their achievements\n* Discussion of challenges faced by AI start-ups, such as:\n\t+ Access to funding and resources\n\t+ Talent acquisition and retention\n\t+ Regulatory compliance and data protection\n* Analysis of government initiatives supporting AI start-ups, such as:\n\t+ Start-up India Seed Fund\n\t+ AI for All (AIFORALL) program\n\n**V. AI Talent and Education**\n\n* Overview of the AI talent landscape in India, including:\n\t+ Number of AI professionals and job market trends\n\t+ AI education and training programs\n* Discussion of the need for AI education and training, including:\n\t+ Skills gap and talent acquisition challenges\n\t+ Importance of AI literacy and awareness\n* Analysis of government initiatives supporting AI education and training, such as:\n\t+ National Policy on Artificial Intelligence\n\t+ AI for All (AIFORALL) program\n\n**VI. Challenges and Concerns**\n\n* Discussion of challenges and concerns related to AI adoption in India, including:\n\t+ Data privacy and security\n\t+ Bias and fairness in AI decision-making\n\t+ Job displacement and unemployment\n\t+ Regulatory compliance and governance\n* Analysis of potential solutions and mitigations, such as:\n\t+ Data protection laws and regulations\n\t+ AI ethics and governance frameworks\n\t+ Upskilling and reskilling programs\n\n**VII. Conclusion**\n\n* Recap of the rise of AI in India and its potential impact\n* Call to action for entrepreneurs, policymakers, and individuals to embrace AI and its opportunities\n* Final thoughts on the future of AI in India and its potential to transform industries and society.\n\n**VIII. References**\n\n* List of sources cited in the blog post, including articles, research papers, and government reports.\n\nThis outline provides a comprehensive structure for a blog post on the rise of AI in India, covering government initiatives, AI adoption in industries, AI start-ups and entrepreneurship, AI talent and education, challenges and concerns, and conclusion.', 'content': '**The Rise of AI in India: Unlocking Opportunities and Transforming Industries**\n\n**I. Introduction**\n\nArtificial Intelligence (AI) has become a transformative force globally, revolutionizing industries and transforming the way we live and work. As the world becomes increasingly dependent on AI, India is poised to become a leader ...

# %%
print(final_state['outline'])
# Out:
# **Title:** "The Rise of AI in India: Unlocking Opportunities and Transforming Industries"
#
# **I. Introduction**
#
# * Brief overview of AI and its growing importance globally
# * Importance of India as a hub for AI innovation and adoption
# * Thesis statement: India is poised to become a leader in AI adoption, driven by government initiatives, technological advancements, and entrepreneurial spirit.
#
# **II. Government Initiatives and Policies**
#
# * Overview of government initiatives such as:
# 	+ Digital India
# 	+ Make in India
# 	+ Start-up India
# 	+ AI for All (AIFORALL)
# * Analysis of policies and regulations supporting AI adoption, such as:
# 	+ Data Protection Bill
# 	+ National Policy on Artificial Intelligence
# * Discussion of government investments in AI research and development
#
# **III. AI Adoption in Indian Industries**
#
# * Overview of AI adoption in various industries, including:
# 	+ Healthcare: AI-powered diagnosis, personalized medicine, and telemedicine
# 	+ Finance: AI-driven banking, credit scoring, and risk management
# 	+ Education: AI-powered learning platforms, adaptive learning, and virtual assistants
# 	+ Retail: AI-driven customer service, inventory management, and supply chain optimization
# 	+ Manufacturing: AI-powered predictive maintenance, quality control, and supply chain optimization
# * Analysis of success stories and case studies of AI adoption in Indian industries
#
# **IV. AI Start-ups and Entrepreneurship**
#
# * Overview of the Indian AI start-up ecosystem, including:
# 	+ Number of AI start-ups and funding trends
# 	+ Notable AI start-ups and their achievements
# * Discussion of challenges faced by AI start-ups, such as:
# 	+ Access to funding and resources
# 	+ Talent acquisition and retention
# 	+ Regulatory compliance and data protection
# * Analysis of government initiatives supporting AI start-ups, such as:
# 	+ Start-up India Seed Fund
# 	+ AI for All (AIFORALL) program
#
# **V. AI Talent and Education**
#
# * Overview of the AI talent landscape in India, including:
# 	+ Number of AI professionals and job market trends
# 	+ AI education and training programs
# * Discussion of the need for AI education and training, including:
# 	+ Skills gap and talent acquisition challenges
# 	+ Importance of AI literacy and awareness
# * Analysis of government initiatives supporting AI education and training, such as:
# 	+ National Policy on Artificial Intelligence
# 	+ AI for All (AIFORALL) program
#
# **VI. Challenges and Concerns**
#
# * Discussion of challenges and concerns related to AI adoption in India, including:
# 	+ Data privacy and security
# 	+ Bias and fairness in AI decision-making
# 	+ Job displacement and unemployment
# 	+ Regulatory compliance and governance
# * Analysis of potential solutions and mitigations, such as:
# 	+ Data protection laws and regulations
# 	+ AI ethics and governance frameworks
# 	+ Upskilling and reskilling programs
#
# **VII. Conclusion**
#
# * Recap of the rise of AI in India and its potential impact
# * Call to action for entrepreneurs, policymakers, and individuals to embrace AI and its opportunities
# * Final thoughts on the future of AI in India and its potential to transform industries and society.
#
# **VIII. References**
#
# * List of sources cited in the blog post, including articles, research papers, and government reports.
#
# This outline provides a comprehensive structure for a blog post on the rise of AI in India, covering government initiatives, AI adoption in industries, AI start-ups and entrepreneurship, AI talent and education, challenges and concerns, and conclusion.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Unlocking Opportunities and Transforming Industries**
#
# **I. Introduction**
#
# Artificial Intelligence (AI) has become a transformative force globally, revolutionizing industries and transforming the way we live and work. As the world becomes increasingly dependent on AI, India is poised to become a leader in AI adoption, driven by government initiatives, technological advancements, and entrepreneurial spirit. With a growing pool of AI talent, a favorable business environment, and a strong focus on innovation, India is well-positioned to unlock the full potential of AI and transform its industries.
#
# The Indian government has recognized the importance of AI and has launched several initiatives to promote its adoption and development. The Digital India program, launched in 2015, aims to make India a digitally empowered society and knowledge economy. The Make in India program, launched in 2014, encourages domestic and foreign companies to manufacture in India. The Start-up India program, launched in 2016, aims to promote entrepreneurship and innovation in India. The AI for All (AIFORALL) program, launched in 2020, aims to promote AI adoption and development in India.
#
# **II. Government Initiatives and Policies**
#
# The Indian government has taken several initiatives to promote AI adoption and development in the country. Some of the key initiatives include:
#
# * **Digital India**: This program aims to make India a digitally empowered society and knowledge economy. It includes initiatives such as the National Digital Health Mission, the National e-Governance Plan, and the Digital India Corporation.
# * **Make in India**: This program encourages domestic and foreign companies to manufacture in India. It includes initiatives such as the Make in India portal, the Make in India awards, and the Make in India export promotion council.
# * **Start-up India**: This program aims to promote entrepreneurship and innovation in India. It includes initiatives such as the Start-up India seed fund, the Start-up India incubation centers, and the Start-up India innovation hub.
# * **AI for All (AIFORALL)**: This program aims to promote AI adoption and development in India. It includes initiatives such as the AI for All challenge, the AI for All hackathon, and the AI for All innovation hub.
#
# The Indian government has also introduced several policies and regulations to support AI adoption and development in the country. Some of the key policies and regulations include:
#
# * **Data Protection Bill**: This bill aims to protect the personal data of Indian citizens. It includes provisions such as data localization, data protection, and data sharing.
# * **National Policy on Artificial Intelligence**: This policy aims to promote AI adoption and development in India. It includes initiatives such as AI research and development, AI education and training, and AI innovation hubs.
# * **Invest India**: This initiative aims to promote foreign investment in India. It includes initiatives such as the Invest India portal, the Invest India awards, and the Invest India export promotion council.
#
# The Indian government has also invested heavily in AI research and development. Some of the key initiatives include:
#
# * **AI research centers**: The Indian government has established several AI research centers in the country, including the AI research center at the Indian Institute of Technology (IIT) Delhi and the AI research center at the Indian Institute of Science (IISc) Bangalore.
# * **AI innovation hubs**: The Indian government has established several AI innovation hubs in the country, including the AI innovation hub at the IIT Delhi and the AI innovation hub at the IISc Bangalore.
# * **AI education and training programs**: The Indian government has introduced several AI education and training programs in the country, including the AI education and training program at the IIT Delhi and the AI education and training program at the IISc Bangalore.
#
# **III. AI Adoption in Indian Industries**
#
# AI is being adopted in various industries in India, including:
#
# * **Healthcare**: AI is being used in healthcare to improve diagnosis, personalize medicine, and provide telemedicine services. Some of the key applications of AI in healthcare include:
# 	+ AI-powered diagnosis: AI is being used to diagnose diseases such as cancer, diabetes, and cardiovascular disease.
# 	+ Personalized medicine: AI is being used to personalize treatment plans for patients based on their genetic profiles and medical histories.
# 	+ Telemedicine: AI is being used to provide telemedicine services to patients in remote areas.
# * **Finance**: AI is being used in finance to improve banking, credit scoring, and risk management. Some of the key applications of AI in finance include:
# 	+ AI-driven banking: AI is being used to provide personalized banking services to customers.
# 	+ Credit scoring: AI is being used to assess the creditworthiness of customers.
# 	+ Risk management: AI is being used to identify and mitigate risks in financial transactions.
# * **Education**: AI is being used in education to improve learning outcomes and provide virtual assistants. Some of the key applications of AI in education include:
# 	+ AI-powered learning platforms: AI is being used to provide personalized learning experiences to students.
# 	+ Adaptive learning: AI is being used to adapt learning materials to the needs of individual students.
# 	+ Virtual assistants: AI is being used to provide virtual assistants to students.
# * **Retail**: AI is being used in retail to improve customer service, inventory management, and supply chain optimization. Some of the key applications of AI in retail include:
# 	+ AI-driven customer service: AI is being used to provide personalized customer service to customers.
# 	+ Inventory management: AI is being used to manage inventory levels and optimize supply chains.
# 	+ Supply chain optimization: AI is being used to optimize supply chains and reduce costs.
# * **Manufacturing**: AI is being used in manufacturing to improve predictive maintenance, quality control, and supply chain optimization. Some of the key applications of AI in manufacturing include:
# 	+ Predictive maintenance: AI is being used to predict when maintenance is required and schedule maintenance accordingly.
# 	+ Quality control: AI is being used to monitor quality and detect defects.
# 	+ Supply chain optimization: AI is being used to optimize supply chains and reduce costs.
#
# **IV. AI Start-ups and Entrepreneurship**
#
# The Indian AI start-up ecosystem is growing rapidly, with many start-ups emerging in the country. Some of the key start-ups in the AI space include:
#
# * **Haptik**: Haptik is a conversational AI start-up that provides chatbots and virtual assistants to businesses.
# * **Frentech**: Frentech is a start-up that provides AI-powered solutions for the education sector.
# * **Zoho**: Zoho is a start-up that provides AI-powered solutions for the enterprise sector.
# * **Tata Consultancy Services (TCS)**: TCS is a start-up that provides AI-powered solutions for the enterprise sector.
#
# The Indian government has introduced several initiatives to support AI start-ups, including:
#
# * **Start-up India Seed Fund**: This fund provides seed funding to start-ups in the AI space.
# * **AI for All (AIFORALL) program**: This program provides funding and support to start-ups in the AI space.
#
# **V. AI Talent and Education**
#
# The Indian AI talent landscape is growing rapidly, with many professionals emerging in the country. Some of the key areas of focus for AI talent development in India include:
#
# * **AI education and training programs**: The Indian government has introduced several AI education and training programs in the country, including the AI education and training program at the IIT Delhi and the AI education and training program at the IISc Bangalore.
# * **AI research centers**: The Indian government has established several AI research centers in the country, including the AI research center at the IIT Delhi and the AI research center at the IISc Bangalore.
# * **AI innovation hubs**: The Indian government has established several AI innovation hubs in the country, including the AI innovation hub at the IIT Delhi and the AI innovation hub at the IISc Bangalore.
#
# **VI. Challenges and Concerns**
#
# While AI has the potential to transform industries and society, there are several challenges and concerns related to its adoption in India, including:
#
# * **Data privacy and security**: AI requires large amounts of data to function effectively, which raises concerns about data privacy and security.
# * **Bias and fairness in AI decision-making**: AI decision-making can be biased and unfair, which raises concerns about its impact on society.
# * **Job displacement and unemployment**: AI has the potential to displace jobs and lead to unemployment, which raises concerns about its impact on the workforce.
# * **Regulatory compliance and governance**: AI requires regulatory compliance and governance, which raises concerns about its impact on businesses and society.
#
# **VII. Conclusion**
#
# In conclusion, AI is transforming industries and society in India, with many start-ups emerging in the country. The Indian government has introduced several initiatives to support AI adoption and development in the country, including the Digital India program, the Make in India program, the Start-up India program, and the AI for All (AIFORALL) program. While there are several challenges and concerns related to AI adoption in India, the potential benefits of AI far outweigh the risks. As AI continues to transform industries and society in India, it is essential to address the challenges and concerns related to its adoption and ensure that its benefits are shared by all.
#
# **VIII. References**
#
# * "The Rise of AI in India: Opportunities and Challenges" by the Indian Institute of Technology (IIT) Delhi.
# * "AI in India: A Report on the Current State and Future Prospects" by the National Association of Software and Services Companies (NASSCOM).
# * "The Impact of AI on the Indian Economy" by the Reserve Bank of India (RBI).
# * "AI in India: A Report on the Current State and Future Prospects" by the Confederation of Indian Industry (CII).
# * "The Rise of AI in India: Opportunities and Challenges" by the Indian Express.
#
# Note: The references provided are fictional and are used only for illustrative purposes.
